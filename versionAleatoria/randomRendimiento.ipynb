# %%
from fire_rescue_model_random import FireRescueModel

# %%
model = FireRescueModel(
    columns=10,
    rows=8,
    num_players=6
)

print("Modelo creado")

for i in range(10):
    model.step()

print("10 steps terminados")
print("Víctimas rescatadas:", model.countRescuedVictims())
print("Víctimas perdidas:", model.countLostVictims())
print("Daño:", model.environment.total_damage_markers)
print("Resultado:", model.game_result)

# %%
import os

print(os.getcwd())
print(os.listdir())

# %%
print("hola")
